# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
file_path= "/content/drive/MyDrive/Copy of Global Terrorism Data.csv"
# Out:
# Mounted at /content/drive

# %%
data= pd.read_csv(file_path,encoding='latin-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# Keeping the necessary features and excluding the others
data = data[["iyear", "imonth", "iday", "country", "country_txt", "region_txt", "city", "success", "attacktype1_txt", "nkill", "propvalue", "targtype1_txt", "latitude", "gname", "longitude", "targsubtype1_txt", "target1", "weaptype1_txt", "weapdetail"]]

# %%
data.head()
# Out:
#    iyear  imonth  iday  country         country_txt  \
# 0   1970       7     2       58  Dominican Republic
# 1   1970       0     0      130              Mexico
# 2   1970       1     0      160         Philippines
# 3   1970       1     0       78              Greece
# 4   1970       1     0      101               Japan
#
#                     region_txt           city  success  \
# 0  Central America & Caribbean  Santo Domingo        1
# 1                North America    Mexico city        1
# 2               Southeast Asia        Unknown        1
# 3               Western Europe         Athens        1
# 4                    East Asia        Fukouka        1
#
#                   attacktype1_txt  nkill  propvalue  \
# 0                   Assassination    1.0        NaN
# 1     Hostage Taking (Kidnapping)    0.0        NaN
# 2                   Assassination    1.0        NaN
# 3               Bombing/Explosion    NaN        NaN
# ...

# %%
#Renaming the Features
data.rename(columns = {'iyear' : 'Year', "imonth" : "Month", "iday" : "Day", "country" : "CountryNo",
                     "country_txt" : "Country", "region_txt" : "Region", "city" : "City", "propvalue" : "PropertyValue",
                     "attacktype1_txt" : "AttackType", "targtype1_txt" : "TargetType", "gname" : "GroupName",
                     "targsubtype1_txt" : "TargetSubType", "target1" : "Target", "nkill" : "NoOfKills",
                     "weaptype1_txt" : "WeaponType", "weapdetail" : "WeaponDetail"}, inplace = True)

# %%
data.head()
# Out:
#    Year  Month  Day  CountryNo             Country  \
# 0  1970      7    2         58  Dominican Republic
# 1  1970      0    0        130              Mexico
# 2  1970      1    0        160         Philippines
# 3  1970      1    0         78              Greece
# 4  1970      1    0        101               Japan
#
#                         Region           City  success  \
# 0  Central America & Caribbean  Santo Domingo        1
# 1                North America    Mexico city        1
# 2               Southeast Asia        Unknown        1
# 3               Western Europe         Athens        1
# 4                    East Asia        Fukouka        1
#
#                        AttackType  NoOfKills  PropertyValue  \
# 0                   Assassination        1.0            NaN
# 1     Hostage Taking (Kidnapping)        0.0            NaN
# 2                   Assassination        1.0            NaN
# 3               Bombing/Explosion        NaN            NaN
# ...

# %%
#Checking the null value in the features
data.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# CountryNo             0
# Country               0
# Region                0
# City                434
# success               0
# AttackType            0
# NoOfKills         10313
# PropertyValue    142702
# TargetType            0
# latitude           4556
# GroupName             0
# longitude          4557
# TargetSubType     10373
# Target              636
# WeaponType            0
# WeaponDetail      67670
# dtype: int64

# %%
#Dealing with the nan values 
data["City"].fillna("Unknown", inplace = True)
data["NoOfKills"].fillna(0, inplace = True)
data["PropertyValue"].fillna(0, inplace = True)
data["Target"].fillna("Unknown", inplace = True)

# %%
data.isnull().sum()
# Out:
# Year                 0
# Month                0
# Day                  0
# CountryNo            0
# Country              0
# Region               0
# City                 0
# success              0
# AttackType           0
# NoOfKills            0
# PropertyValue        0
# TargetType           0
# latitude          4556
# GroupName            0
# longitude         4557
# TargetSubType    10373
# Target               0
# WeaponType           0
# WeaponDetail     67670
# dtype: int64

# %%
#Visualizing attacks per year with CountPlot chart
plt.figure(figsize=(24,12))
sns.countplot(x = "Year", data = data)
plt.title("Attacks per Year")
# Out:
# Text(0.5, 1.0, 'Attacks per Year')

# %%
#Visualizing the attacks per year with success and failures data by bar chart
plt.figure(figsize=(24,12))
sns.countplot(x = "Year", hue = "success", data = data)
plt.title("Success vs Failure")
# Out:
# Text(0.5, 1.0, 'Success vs Failure')

# %% [markdown]
# Region wise terrorist Activities
#
# Here we are findout which region mostly affected by trrorism

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'CountryNo', 'Country', 'Region', 'City',
#        'success', 'AttackType', 'NoOfKills', 'PropertyValue', 'TargetType',
#        'latitude', 'GroupName', 'longitude', 'TargetSubType', 'Target',
#        'WeaponType', 'WeaponDetail'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Year           181691 non-null  int64
#  1   Month          181691 non-null  int64
#  2   Day            181691 non-null  int64
#  3   CountryNo      181691 non-null  int64
#  4   Country        181691 non-null  object
#  5   Region         181691 non-null  object
#  6   City           181691 non-null  object
#  7   success        181691 non-null  int64
#  8   AttackType     181691 non-null  object
#  9   NoOfKills      181691 non-null  float64
#  10  PropertyValue  181691 non-null  float64
#  11  TargetType     181691 non-null  object
#  12  latitude       177135 non-null  float64
#  13  GroupName      181691 non-null  object
#  14  longitude      177134 non-null  float64
#  15  TargetSubType  171318 non-null  object
#  16  Target         181691 non-null  object
# ...

# %%
data.head()
# Out:
#    Year  Month  Day  CountryNo             Country  \
# 0  1970      7    2         58  Dominican Republic
# 1  1970      0    0        130              Mexico
# 2  1970      1    0        160         Philippines
# 3  1970      1    0         78              Greece
# 4  1970      1    0        101               Japan
#
#                         Region           City  success  \
# 0  Central America & Caribbean  Santo Domingo        1
# 1                North America    Mexico city        1
# 2               Southeast Asia        Unknown        1
# 3               Western Europe         Athens        1
# 4                    East Asia        Fukouka        1
#
#                        AttackType  NoOfKills  PropertyValue  \
# 0                   Assassination        1.0            0.0
# 1     Hostage Taking (Kidnapping)        0.0            0.0
# 2                   Assassination        1.0            0.0
# 3               Bombing/Explosion        0.0            0.0
# ...

# %%
data['TargetType'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: TargetType, dtype: int64

# %%
azerbaijan=data[data['Country']=='Azerbaijan']

# %%
azerbaijan['Year'].value_counts()
# Out:
# 1992    12
# 1994    11
# 2001     4
# 1991     3
# 2014     3
# 1995     2
# 1996     2
# 2008     2
# 2009     2
# 2016     2
# 2017     2
# 1997     1
# 2000     1
# 2002     1
# 2007     1
# Name: Year, dtype: int64

# %%
year_count=azerbaijan['Year'].value_counts()

# %%
# Number of terror acts in Azerbaijan over the years
sns.lineplot(x=year_count.index, y=year_count.values)
plt.xlabel('Years')
plt.ylabel('Number of terror')
plt.title('Number of terror acts in Azerbaijan over the years')
plt.show()

# %%
gname=data[data['GroupName']!='Unknown']['GroupName'].value_counts()

# %%
gname
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
#                                                     ...
# Ansar Sarallah                                         1
# Sword of Islam                                         1
# Support of Ocalan-The Hawks of Thrace                  1
# Arab Revolutionary Front                               1
# MANO-D                                                 1
# Name: GroupName, Length: 3536, dtype: int64

# %%
# 20 terrorist groups with the highest terror attacks
top_20=gname.head(20)
plt.figure(figsize=(15, 8))
sns.barplot(x=top_20.index, y=top_20.values)
plt.xticks(rotation=90)
plt.title('20 terrorist groups with the highest terror attacks')
plt.show()

# %%
azerbaijan['GroupName'].value_counts()
# Out:
# Unknown                     34
# Azerbaijan Guerrillas        7
# Armenian Guerrillas          2
# Forest Brothers              2
# Opposition Group             1
# Sandval (union) Movement     1
# Yekbun                       1
# Separatists                  1
# Name: GroupName, dtype: int64

# %%
az_gname=azerbaijan['GroupName'].value_counts()

# %%
# Terrorist groups committing terror acts in Azerbaijan
plt.figure(figsize=(18, 6))
langs = az_gname.index
count=az_gname.values
plt.pie(count, labels = langs, autopct='%1.2f%%')
plt.title('Terrorist groups committing terror acts in Azerbaijan')
plt.show()

# %%
top_20_terror=data.sort_values('NoOfKills', ascending=False).head(20)

# %%
top_20_terror['Country'].value_counts()
# Out:
# Iraq                                5
# United States                       2
# Syria                               2
# Rwanda                              1
# Somalia                             1
# Nepal                               1
# Iran                                1
# Democratic Republic of the Congo    1
# Mozambique                          1
# Burundi                             1
# Russia                              1
# Canada                              1
# Sri Lanka                           1
# Nigeria                             1
# Name: Country, dtype: int64

# %%
country_count=data['Country'].value_counts()

# %%
geog=pd.DataFrame({'Country':country_count.index, 'number_of_attacks':country_count.values})

# %%
geog.head()
# Out:
#        Country  number_of_attacks
# 0         Iraq              24636
# 1     Pakistan              14368
# 2  Afghanistan              12731
# 3        India              11960
# 4     Colombia               8306

# %%
data['AttackType'].value_counts().plot.bar()

# %%
data.head()
# Out:
#    Year  Month  Day  CountryNo             Country  \
# 0  1970      7    2         58  Dominican Republic
# 1  1970      0    0        130              Mexico
# 2  1970      1    0        160         Philippines
# 3  1970      1    0         78              Greece
# 4  1970      1    0        101               Japan
#
#                         Region           City  success  \
# 0  Central America & Caribbean  Santo Domingo        1
# 1                North America    Mexico city        1
# 2               Southeast Asia        Unknown        1
# 3               Western Europe         Athens        1
# 4                    East Asia        Fukouka        1
#
#                        AttackType  NoOfKills  PropertyValue  \
# 0                   Assassination        1.0            0.0
# 1     Hostage Taking (Kidnapping)        0.0            0.0
# 2                   Assassination        1.0            0.0
# 3               Bombing/Explosion        0.0            0.0
# ...

# %% [markdown]
# # Terrorist Activities by Region in each Year through Area Plot

# %%
# Terrorist Activities by Region in each Year # Number of Attacks
pd.crosstab(data.year, data.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-ed99a38ed45c> in <module>()
#       1 # Terrorist Activities by Region in each Year # Number of Attacks
# ----> 2 pd.crosstab(data.year, data.Region).plot(kind='area',figsize=(15,6))
#       3 plt.title('Terrorist Activities by Region in each Year')
#       4 plt.ylabel('Number of Attacks')
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'
